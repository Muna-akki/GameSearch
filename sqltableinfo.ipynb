# %% [markdown]
# 以下に出てくる表は<a>http://erogamescape.dyndns.org/~ap2/ero/toukei_kaiseki/sql_for_erogamer_tablelist.php</a>からHTMLをそのままコピペ

# %% [markdown]
# # ブランド情報
# ## blandlist
#
# <dd id="brandlist_table" class="display-none" style="display: block;">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>brandname</td><td>text</td><td>ブランドの名前</td></tr>
# <tr><td>brandfurigana</td><td>text</td><td>ブランドの名前のフリガナ</td></tr>
# <tr><td>makername</td><td>text</td><td>未使用</td></tr>
# <tr><td>makerfurigana</td><td>text</td><td>未使用</td></tr>
# <tr><td>url</td><td>text</td><td>ブランドのOHPのURL</td></tr>
# <tr><td>checked</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>kind</td><td>text</td><td>CORPORATION(企業)かCIRCLE(同人)か</td></tr>
# <tr><td>lost</td><td>boolean</td><td>TRUEなら解散</td></tr>
# <tr><td>directlink</td><td>boolean</td><td>TRUEならトップページ以外へのリンク不可</td></tr>
# <tr><td>median</td><td>integer</td><td>ブランドが作ったゲームの中央値、1日1回計算されて格納される</td></tr>
# <tr><td>http_response_code</td><td>integer</td><td>管理用</td></tr>
# <tr><td>twitter</td><td>text</td><td>ブランド公式twitterのID</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ゲーム情報
# ## gamelist
# <dd id="gamelist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>gamename</td><td>text</td><td>ゲームの名前</td></tr>
# <tr><td>furigana</td><td>text</td><td>ゲームの名前のフリガナ</td></tr>
# <tr><td>sellday</td><td>date</td><td>発売日、発売日が決まっていない場合は2030-01-01</td></tr>
# <tr><td>brandname</td><td>integer</td><td>brandlistテーブルのidを参照する外部キー</td></tr>
# <tr><td>median</td><td>integer</td><td>ゲームの得点の中央値、1日1回計算して格納している</td></tr>
# <tr><td>stdev</td><td>integer</td><td>ゲームの得点の標準偏差、1日1回計算して格納している</td></tr>
# <tr><td>creater</td><td>integer</td><td>未使用</td></tr>
# <tr><td>kansouurl</td><td>text</td><td>未使用</td></tr>
# <tr><td>checked</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>hanbaisuu</td><td>integer</td><td>未使用</td></tr>
# <tr><td>average2</td><td>integer</td><td>未使用</td></tr>
# <tr><td>median2</td><td>integer</td><td>未使用</td></tr>
# <tr><td>count2</td><td>integer</td><td>ゲームの得点のデータ数、1日1回計算して格納している</td></tr>
# <tr><td>comike</td><td>integer</td><td><a href="http://www.getchu.com/top.html">Getchu.com</a>のID</td></tr>
# <tr><td>shoukai</td><td>text</td><td>ゲームのOHPのURL</td></tr>
# <tr><td>model</td><td>text</td><td>ゲームの機種</td></tr>
# <tr><td>checked2</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>erogame</td><td>boolean</td><td>エロゲか否か、tはエロゲー、fは非エロゲー</td></tr>
# <tr><td>galge</td><td>text</td><td>未使用</td></tr>
# <tr><td>elfics</td><td>text</td><td>未使用</td></tr>
# <tr><td>banner_url</td><td>text</td><td>バナーのURL</td></tr>
# <tr><td>admin_checked</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>max2</td><td>integer</td><td>未使用</td></tr>
# <tr><td>min2</td><td>integer</td><td>未使用</td></tr>
# <tr><td>gyutto_enc</td><td>text</td><td>未使用</td></tr>
# <tr><td>gyutto_id</td><td>integer</td><td><a href="http://gyutto.com/">Gyutto.com</a>のID</td></tr>
# <tr><td>dmm</td><td>text</td><td><a href="http://www.dmm.co.jp/">FANZA</a>のID</td></tr>
# <tr><td>dmm_genre</td><td>text</td><td><a href="http://www.dmm.co.jp/">FANZA</a>のURLの一部</td></tr>
# <tr><td>dmm_genre_2</td><td>text</td><td><a href="http://www.dmm.co.jp/">FANZA</a>のURLの一部</td></tr>
# <tr><td>erogametokuten</td><td>integer</td><td></td></tr>
# <tr><td>total_play_time_median</td><td>integer</td><td></td></tr>
# <tr><td>time_before_understanding_fun_median</td><td>integer</td><td></td></tr>
# <tr><td>dlsite_id</td><td>text</td><td></td></tr>
# <tr><td>dlsite_domain</td><td>text</td><td></td></tr>
# <tr><td>the_number_of_uid_which_input_pov</td><td>integer</td><td></td></tr>
# <tr><td>the_number_of_uid_which_input_play</td><td>integer</td><td></td></tr>
# <tr><td>total_pov_enrollment_of_a</td><td>integer</td><td></td></tr>
# <tr><td>total_pov_enrollment_of_b</td><td>integer</td><td></td></tr>
# <tr><td>total_pov_enrollment_of_c</td><td>integer</td><td></td></tr>
# <tr><td>trial_url</td><td>text</td><td></td></tr>
# <tr><td>trial_h</td><td>boolean</td><td></td></tr>
# <tr><td>http_response_code</td><td>integer</td><td>管理用</td></tr>
# <tr><td>okazu</td><td>boolean</td><td></td></tr>
# <tr><td>axis_of_soft_or_hard</td><td>integer</td><td></td></tr>
# <tr><td>trial_url_update_time</td><td>timestamp without time zone</td><td></td></tr>
# <tr><td>genre</td><td>text</td><td></td></tr>
# <tr><td>twitter</td><td>text</td><td></td></tr>
# <tr><td>erogetrailers</td><td>integer</td><td></td></tr>
# <tr><td>tourokubi</td><td>date</td><td></td></tr>
# <tr><td>digiket</td><td>text</td><td></td></tr>
# <tr><td>dmm_sample_image_count</td><td>integer</td><td></td></tr>
# <tr><td>dlsite_sample_image_count</td><td>integer</td><td></td></tr>
# <tr><td>gyutto_sample_image_count</td><td>integer</td><td></td></tr>
# <tr><td>digiket_sample_image_count</td><td>integer</td><td></td></tr>
# <tr><td>twitter_search</td><td>twitter_search</td><td></td></tr>
# <tr><td>tgfrontier</td><td>integer</td><td></td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # クリエイター情報
# ## createrlist
# <dd id="createrlist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>name</td><td>text</td><td>クリエイターの名前</td></tr>
# <tr><td>furigana</td><td>text</td><td>クリエイターの名前のフリガナ</td></tr>
# <tr><td>title</td><td>text</td><td>クリエイターのOHPのタイトル</td></tr>
# <tr><td>url</td><td>text</td><td>クリエイターのOHPのURL</td></tr>
# <tr><td>circle</td><td>text</td><td>クリエイターのサークル名</td></tr>
# <tr><td>betumei</td><td>integer</td><td>未使用</td></tr>
# <tr><td>checked</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>twitter_username</td><td>text</td><td>クリエイターのtwitterのID</td></tr>
# <tr><td>twitter_id</td><td>integer</td><td>未使用</td></tr>
# <tr><td>http_response_code</td><td>integer</td><td>管理用</td></tr>
# <tr><td>blog</td><td>text</td><td>クリエイターのBLOGのURL</td></tr>
# <tr><td>pixiv</td><td>integer</td><td>クリエイターのpixivのID</td></tr>
# <tr><td>blog_title</td><td>text</td><td>クリエイターのBLOGのタイトル</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 職種(ゲームとクリエイターを関連付ける情報)
# ## shokushu
#
# <dd id="shokushu_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー</td></tr>
# <tr><td>creater</td><td>integer</td><td>createrlistテーブルのidを参照する外部キー</td></tr>
# <tr><td>shubetu</td><td>integer</td><td>職種 1: 原画 2:シナリオ 3:音楽 4:キャラデザ 5:声優 6:歌手 7:その他</td></tr>
# <tr><td>checked</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>note</td><td>text</td><td>未使用</td></tr>
# <tr><td>shubetu_detail</td><td>integer</td><td>1:メイン 2:サブ 3:その他</td></tr>
# <tr><td>shubetu_detail_name</td><td>text</td><td>声優の場合は役名、その他の場合は職種名が登録される</td></tr>
# <tr><td>ip</td><td>text</td><td>管理用</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>データの登録日時</td></tr>
# <tr><td>sort_num</td><td>integer</td><td>未使用(表示をOHPに準拠できるように列だけ作りました…)</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ユーザー情報
# ## myuserreview
# <dd id="myuserview_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>uid</td><td>text</td><td>ユーザーID</td></tr>
# <tr><td>title</td><td>text</td><td>ユーザーさんのHPのタイトル</td></tr>
# <tr><td>url</td><td>text</td><td>ユーザーさんのHPのURL</td></tr>
# <tr><td>hitokoto</td><td>text</td><td>一言</td></tr>
# <tr><td>touhyou</td><td>boolean</td><td>管理用 </td></tr>
# <tr><td>choubun_ress</td><td>boolean</td><td>管理用 </td></tr>
# <tr><td>birth</td><td>integer</td><td>ユーザーさんの誕生年(西暦)</td></tr>
# <tr><td>sex</td><td>boolean</td><td>ユーザーさんの性 t:男性 f:女性</td></tr>
# <tr><td>userreview_log</td><td>boolean</td><td>管理用 </td></tr>
# <tr><td>twitter_username</td><td>character varying(20)</td><td>ユーザーさんのtwitterのID</td></tr>
# <tr><td>user_only_possession_display</td><td>boolean</td><td>管理用 </td></tr>
# <tr><td>filter_avg_min</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>filter_avg_max</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>filter_stddev_min</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>filter_stddev_max</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>filter_tokuten_count_min</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>filter_hitokoto_count_min</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>filter_memo_count_min</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>filter_active_user_day</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>filter_old_user_day</td><td>integer</td><td>スマホ用フィルタ設定の1つ</td></tr>
# <tr><td>user_pleased_display</td><td>boolean</td><td>管理用 </td></tr>
# <tr><td>total_play_display</td><td>boolean</td><td>管理用 </td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ユーザーの得点・一言感想等の情報
# ## userreview
# <dd id="userreview_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー</td></tr>
# <tr><td>uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー</td></tr>
# <tr><td>tokuten</td><td>integer</td><td>ゲームの得点</td></tr>
# <tr><td>tourokubi</td><td>timestamp with time zone</td><td>一言感想を登録した登録日時</td></tr>
# <tr><td>hitokoto</td><td>character varying(400)</td><td>一言感想</td></tr>
# <tr><td>memo</td><td>text</td><td>長文感想</td></tr>
# <tr><td>netabare</td><td>boolean</td><td>長文感想のネタバレ具合 t:ネタバレ f:ネタバレなし</td></tr>
# <tr><td>id</td><td>integer</td><td>管理用 </td></tr>
# <tr><td>giveup</td><td>boolean</td><td>あきらめたか否か t: あきらめた f:クリアした</td></tr>
# <tr><td>possession</td><td>boolean</td><td>所持しているか否か t: 所持 f:所持していない</td></tr>
# <tr><td>play</td><td>boolean</td><td>プレイしたか否か t: プレイした f:プレイしていない</td></tr>
# <tr><td>reserve</td><td>boolean</td><td>未使用</td></tr>
# <tr><td>outline</td><td>text</td><td>未使用</td></tr>
# <tr><td>before_hitokoto</td><td>text</td><td>発売前一言</td></tr>
# <tr><td>before_tokuten</td><td>integer</td><td>発売前得点</td></tr>
# <tr><td>before_tourokubi</td><td>timestamp without time zone</td><td>発売前一言感想を登録した登録日時</td></tr>
# <tr><td>outline_hitokoto</td><td>character varying(400)</td><td>未使用</td></tr>
# <tr><td>display</td><td>boolean</td><td>データ登録画面の表示有無 t:表示 f:非表示</td></tr>
# <tr><td>play_tourokubi</td><td>timestamp without time zone</td><td>play列がtとなった日時</td></tr>
# <tr><td>outline_netabare</td><td>boolean</td><td>未使用</td></tr>
# <tr><td>outline_tourokubi</td><td>timestamp without time zone</td><td>未使用</td></tr>
# <tr><td>display_unique_count</td><td>integer</td><td>長文感想の参照数</td></tr>
# <tr><td>sage</td><td>boolean</td><td>一言感想をトップページに表示するか否か t:表示 f:表示しない</td></tr>
# <tr><td>before_purchase_will</td><td>text</td><td>購入予定 0_必ず購入 多分購入 様子見</td></tr>
# <tr><td>before_sage</td><td>boolean</td><td>発売前一言をトップページに表示するか否か t:表示 f:表示しない</td></tr>
# <tr><td>total_play_time</td><td>integer</td><td>総プレイ時間</td></tr>
# <tr><td>time_before_understanding_fun</td><td>integer</td><td>面白さが分かるまでのプレイ時間</td></tr>
# <tr><td>okazu_tokuten</td><td>integer</td><td>どの程度おかずに使えたか 4:とても使えた 3:かなり使えた 2:だいぶ使えた 1:それなりに使えた -1:あまり使えなかった -2:まったく使えなかった -998:そもそも趣向があわなかった -999:未登録</td></tr>
# <tr><td>trial_version_hitokoto</td><td>text</td><td>体験版一言</td></tr>
# <tr><td>trial_version_hitokoto_sage</td><td>boolean</td><td>体験版一言をトップページに表示するか否か t:表示 f:表示しない</td></tr>
# <tr><td>trial_version_hitokoto_tourokubi</td><td>timestamp without time zone</td><td>体験版一言を登録した登録日時</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>データが登録された日時</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ユーザーのお気に入りクリエイターの情報
# ## usercreater
# <dd id="usercreater_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー</td></tr>
# <tr><td>creater</td><td>integer</td><td>createrlistテーブルのidを参照する外部キー</td></tr>
# <tr><td>comment</td><td>text</td><td>クリエイターさんに関するコメント</td></tr>
# <tr><td>rank</td><td>integer</td><td>好きなランク</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>データが登録された日時</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # POVの情報
# ## povlist
# <dd id="povlist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー </td></tr>
# <tr><td>title</td><td>character varying(100)</td><td>POVの名前 </td></tr>
# <tr><td>comment</td><td>text</td><td>POVの説明</td></tr>
# <tr><td>uid</td><td>text</td><td>POVを登録したユーザーID</td></tr>
# <tr><td>timestamp</td><td>timestamp with time zone</td><td>未使用</td></tr>
# <tr><td>tourokubi</td><td>timestamp with time zone</td><td>POVが登録された日時</td></tr>
# <tr><td>furigana</td><td>text</td><td>POVの名前のフリガナ</td></tr>
# <tr><td>editingday</td><td>timestamp with time zone</td><td>POVの登録内容を修正した日時</td></tr>
# <tr><td>registration</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>system_title</td><td>text</td><td>POVの短縮名</td></tr>
# <tr><td>system_group</td><td>text</td><td>POVが属するグループ名</td></tr>
# <tr><td>netabare</td><td>boolean</td><td>ネタバレの有り無し t:ネタバレ f:非ネタバレ</td></tr>
# <tr><td>number_of_user</td><td>integer</td><td>未使用</td></tr>
# <tr><td>before</td><td>boolean</td><td>発売前のゲームにPOVを登録可能か否か</td></tr>
# <tr><td>before_trial</td><td>boolean</td><td>発売前で体験版があるゲームにPOVを登録可能か否か</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ユーザーがゲームにくくりつけたPOVの情報
# ## povgroups
# <dd id="povgroups_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー </td></tr>
# <tr><td>uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー </td></tr>
# <tr><td>pov</td><td>integer</td><td>povlistテーブルのidを参照する外部キー </td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>rank</td><td>character(1)</td><td>ランク、A、B、C</td></tr>
# <tr><td>memo</td><td>text</td><td>コメント</td></tr>
# <tr><td>tourokubi</td><td>timestamp with time zone</td><td>登録された日時</td></tr>
# <tr><td>sage</td><td>boolean</td><td>コメントをトップページに表示するか否か t:表示 f:表示しない</td></tr>
# <tr><td>modified</td><td>timestamp without time zone</td><td>管理用</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 各ゲームの統計情報(毎日一回更新)
# ## toukei_temp_table
# <dd id="toukei_temp_table_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>gamename</td><td>text</td><td>ゲーム名、gamelistのgamenameと同じ</td></tr>
# <tr><td>brandname</td><td>text</td><td>ブランド名、brandlistのbrandnameと同じ</td></tr>
# <tr><td>sellday</td><td>date</td><td>発売日、gamelistのselldayと同じ</td></tr>
# <tr><td>median</td><td>integer</td><td>中央値、userreviewとreviewpagelistのtokuten列がnullでない値の中央値</td></tr>
# <tr><td>average</td><td>real</td><td>平均値、userreviewとreviewpagelistのtokuten列がnullでない値の平均値</td></tr>
# <tr><td>stddev</td><td>integer</td><td>標準偏差、userreviewとreviewpagelistのtokuten列がnullでない値の標準偏差</td></tr>
# <tr><td>count</td><td>integer</td><td>得点のデータ数、userreviewとreviewpagelistのtokuten列がnullでない値の数</td></tr>
# <tr><td>allcount</td><td>integer</td><td>プレイしたユーザーの数、userreviewでplay列がtrueの数とreviewpagelistを足した数</td></tr>
# <tr><td>game_id</td><td>integer</td><td>gamelistのid</td></tr>
# <tr><td>brand_id</td><td>integer</td><td>brandlistのid</td></tr>
# <tr><td>coterie</td><td>integer</td><td>同人ゲーム:gamelistのid 非同人ゲーム:null つまりこの列に数字が入っていれば同人ゲーム</td></tr>
# <tr><td>erogame</td><td>boolean</td><td>t:18禁 f:非18禁</td></tr>
# <tr><td>model</td><td>text</td><td>機種、gamelistのmodelと同じ</td></tr>
# <tr><td>boyslove</td><td>integer</td><td>ボーイズラブ:gamelistのid 非ボーイズラブ:null つまりこの列に数字が入っていればボーイズラブ</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # タグの情報
# ## taglist
# <dd id="taglist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>name</td><td>text</td><td>タグ名</td></tr>
# <tr><td>furigana</td><td>text</td><td>未使用</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>タグが登録された日時</td></tr>
# <tr><td>netabare</td><td>boolean</td><td>ネタバレ具合 t:ネタバレ f:ネタバレなし</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ユーザーがゲームにくくりつけたタグの情報
# <dd id="userreview_with_tag_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>tag</td><td>text</td><td>taglistテーブルのidを参照する外部キー</td></tr>
# <tr><td>uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー</td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー</td></tr>
# <tr><td>comment</td><td>text</td><td>コメント</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>タグがゲームに括り付けられた日時</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # お気に入りユーザー
# ## user_user
# <dd id="user_user_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー 、気に入られた側のユーザーID</td></tr>
# <tr><td>voter_uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー  、気に入った側のユーザーID</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>お気に入りに登録された日時</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 投票された感想の情報
# ## userreview_touhyou
# <dd id="userreview_touhyou_table" class="display-none">
# myuserテーブルのuidを参照する外部キー 、投票それた側側のユーザーID<table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー</td></tr>
# <tr><td>uid</td><td>text</td><td></td></tr>
# <tr><td>voter_uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー  、投票した側のユーザーID</td></tr>
# <tr><td>hitokoto</td><td>text</td><td>一言</td></tr>
# <tr><td>timestamp</td><td>timestamp with time zone</td><td>投票された日時</td></tr>
# <tr><td>sage</td><td>boolean</td><td>投票したことをトップページに表示するか否か t:表示 f:表示しない</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ゲームグループの情報。任意のグループを作ってグループにゲームをくくりつけられる。
# ## gamegrouplist
# <dd id="gamegrouplist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>name</td><td>text</td><td>ゲームグループ名</td></tr>
# <tr><td>furigana</td><td>text</td><td>ゲームグループ名のフリガナ</td></tr>
# <tr><td>median</td><td>integer</td><td>未使用</td></tr>
# <tr><td>check_add</td><td>boolean</td><td>管理用</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ゲームグループとゲームをくくりつける情報
# # belong_to_gamegroup_list
# <dd id="belong_to_gamegroup_list_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>gamegroup</td><td>integer</td><td>gamegroupテーブルのidを参照する外部キー </td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー</td></tr>
# <tr><td>check_add</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>reservation_del</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>memo</td><td>text</td><td>未使用</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ゲームが動作したOSの候補
# ## platformlist
# <dd id="platformlist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>name</td><td>text</td><td>OS</td></tr>
# <tr><td>sort</td><td>integer</td><td>ソート用</td></tr>
# <tr><td>model</td><td>text</td><td>機種</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 動作したOSの情報
# ## support_platform
#
# <dd id="support_platform_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー </td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>platform</td><td>integer</td><td>platformlistテーブルのidを参照する外部キー </td></tr>
# <tr><td>operation</td><td>integer</td><td>動作状況 1:動作 2:条件付きで動作 3:動作不可・インストール不可</td></tr>
# <tr><td>memo</td><td>text</td><td>任意のメモ</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>動作したOSの情報が登録された日時</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ホームページ(レビューサイト)の情報
# ## homepagelist
#
# <dd id="homepagelist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー </td></tr>
# <tr><td>title</td><td>text</td><td>ホームページのタイトル</td></tr>
# <tr><td>furigana</td><td>text</td><td>ホームページのタイトルのフリガナ</td></tr>
# <tr><td>url</td><td>text</td><td>ホームページのURL</td></tr>
# <tr><td>admin</td><td>text</td><td>管理者の名前</td></tr>
# <tr><td>tokuten</td><td>boolean</td><td>得点の有無 t:得点表記あり f:得点表記なし</td></tr>
# <tr><td>checked</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>reviewsite</td><td>boolean</td><td>管理用</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # レビューサイトのレビューの情報
# ## reviewpagelist
#
# <dd id="reviewpagelist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー </td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>reviewpage</td><td>integer</td><td>homepagelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>tokuten</td><td>integer</td><td>得点</td></tr>
# <tr><td>tourokubi</td><td>timestamp with time zone</td><td>登録日時</td></tr>
# <tr><td>memo</td><td>text</td><td>メモ</td></tr>
# <tr><td>link</td><td>text</td><td>レビュー記事のURL</td></tr>
# <tr><td>checked</td><td>boolean</td><td>管理用</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 属性の情報
# ## attributelist
#
# <dd id="attributelist_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー </td></tr>
# <tr><td>title</td><td>text</td><td>属性の名前</td></tr>
# <tr><td>furigana</td><td>text</td><td>属性のフリガナ<br>フリガナの先頭に01と数字がついている<br>数字でジャンル分けをしている<br>01:ジャンル 02:声 03:メーカー配布 04:起動 05:システム 06:スクリプト 07:動作環境 08:他機種 09:販売方法 10:作品形態 11:アニメ 12:主人公 13:描写 0:その他</td></tr>
# <tr><td>explain</td><td>text</td><td>未使用</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 属性とゲーム情報をくくりつける情報
# ## attributegroupsboolean
# <dd id="attributegroupsboolean_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー </td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>attribute</td><td>integer</td><td>attributelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>boolean</td><td>boolean</td><td>未使用、常にt</td></tr>
# <tr><td>lock</td><td>boolean</td><td>データ削除可能かのフラグ t:削除不可 f:削除可能</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ユーザーのuserreviewテーブルの統計情報。毎時一回更新
# ## userreview_toukei_table
# <dd id="userreview_toukei_table_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>uid</td><td>text</td><td>ユーザーID</td></tr>
# <tr><td>tokuten_avg</td><td>integer</td><td>ユーザーさんのつけた得点の平均値</td></tr>
# <tr><td>tokuten_stddev</td><td>integer</td><td>ユーザーさんのつけた得点の標準偏差</td></tr>
# <tr><td>tokuten_count</td><td>integer</td><td>ユーザーさんのつけた得点の数</td></tr>
# <tr><td>tourokubi_max</td><td>timestamp with time zone</td><td>ユーザーさんが最後に一言感想を登録した日時</td></tr>
# <tr><td>tourokubi_min</td><td>timestamp with time zone</td><td>ユーザーさんが最初に一言感想を登録した日時</td></tr>
# <tr><td>hitokoto_count</td><td>integer</td><td>ユーザーさんの書いた一言感想の数</td></tr>
# <tr><td>memo_count</td><td>integer</td><td>ユーザーさんの書いた長文感想の数</td></tr>
# <tr><td>before_hitokoto_count</td><td>integer</td><td>ユーザーさんの書いた発売前一言感想の数</td></tr>
# <tr><td>before_tokuten_avg</td><td>integer</td><td>ユーザーさんのつけた発売前得点の平均値</td></tr>
# <tr><td>before_tokuten_stddev</td><td>integer</td><td>ユーザーさんのつけた発売前得点の標準偏差</td></tr>
# <tr><td>before_tokuten_count</td><td>integer</td><td>ユーザーさんのつけた発売前得点の数</td></tr>
# <tr><td>trial_hitokoto_count</td><td>integer</td><td>ユーザーさんの書いた体験版一言感想の数</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 毎月一回生成するゲームの得点ランキングの平均値Ver
# ## junnirireki
# <dd id="junnirireki_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>date</td><td>date</td><td>この行が挿入された日</td></tr>
# <tr><td>avg</td><td>real</td><td>平均値</td></tr>
# <tr><td>count</td><td>integer</td><td>データ数</td></tr>
# <tr><td>junni</td><td>integer</td><td>順位</td></tr>
# <tr><td>junni_old</td><td>integer</td><td>前回順位</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 毎月一回生成するゲームの得点ランキングの中央値Ver
# ## junirirekimedian
# <dd id="junirirekimedian_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>date</td><td>date</td><td>この行が挿入された日</td></tr>
# <tr><td>median</td><td>real</td><td>中央値</td></tr>
# <tr><td>count</td><td>integer</td><td>データ数</td></tr>
# <tr><td>junni</td><td>integer</td><td>順位</td></tr>
# <tr><td>junni_old</td><td>integer</td><td>前回順位</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # 毎月一回生成するゲームの得点ランキングの上下10%の値を除いた平均値Ver
# ## junirirekiavgtenpersent
# <dd id="junirirekiavgtenpersent_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>date</td><td>date</td><td>この行が挿入された日</td></tr>
# <tr><td>avg</td><td>real</td><td>得点の上位下位10%を削って求めた平均値</td></tr>
# <tr><td>count</td><td>integer</td><td>データ数</td></tr>
# <tr><td>junni</td><td>integer</td><td>順位</td></tr>
# <tr><td>junni_old</td><td>integer</td><td>前回順位</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ユーザーが作成したSQLの情報
# ## usersql
# <dd id="usersql_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>uid</td><td>text</td><td>myuserテーブルのuidを参照する外部キー </td></tr>
# <tr><td>sql</td><td>text</td><td>SQL</td></tr>
# <tr><td>title</td><td>text</td><td>SQLのタイトル</td></tr>
# <tr><td>explanation</td><td>text</td><td>SQLの説明</td></tr>
# <tr><td>create_timestamp</td><td>timestamp with time zone</td><td>SQLが登録された日時</td></tr>
# <tr><td>update_timestamp</td><td>timestamp with time zone</td><td>SQLが更新された日時</td></tr>
# <tr><td>public_open</td><td>boolean</td><td>公開するか否か t:公開 f:非公開</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # kensaku.phpから検索された言葉の記録。たまにserch_word_hisに移動する
# ## serch_word
# <dd id="serch_word_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>category</td><td>text</td><td>検索のカテゴリ、2014/01/02現在はgameのみ</td></tr>
# <tr><td>word</td><td>text</td><td>検索された言葉</td></tr>
# <tr><td>media</td><td>text</td><td>機種、2014/01/02現在はPCのみ</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>検索された日時</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # kensaku.phpから検索された言葉の記録
# ## serch_word_his
# <dd id="serch_word_his_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>category</td><td>text</td><td>検索のカテゴリ、2014/01/02現在はgameのみ</td></tr>
# <tr><td>word</td><td>text</td><td>検索された言葉</td></tr>
# <tr><td>media</td><td>text</td><td>機種、2014/01/02現在はPCのみ</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>検索された日時</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # HolysealのゲームIDとErogameScapeのゲームIDをくくりつける情報
# ## holyseal
#
# <dd id="holyseal_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー</td></tr>
# <tr><td>holyseal_id</td><td>integer</td><td>HolysealのゲームID</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # ゲームとゲームの関連付けの情報
# ## connection_between_lists_of_gemes
#
# <dd id="connection_between_lists_of_games_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>id</td><td>integer</td><td>主キー</td></tr>
# <tr><td>game_subject</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー、●●は××のファンディスク…と●●の方</td></tr>
# <tr><td>game_object</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー、●●は××のファンディスク…と××の方</td></tr>
# <tr><td>reservation_del</td><td>boolean</td><td>管理用</td></tr>
# <tr><td>kind</td><td>text</td><td>関連づけの種別 fandisk:ファンディスク remake:リメイク transplant:移植版 bundling:同梱 sequel:続編 apend:アペンド</td></tr>
# <tr><td>memo</td><td>text</td><td>メモ</td></tr>
# <tr><td>timestamp</td><td>timestamp without time zone</td><td>データが登録された日時</td></tr>
# <tr><td>freeze_flag</td><td>boolean</td><td>管理用</td></tr>
# </tbody></table>
# </dd>

# %% [markdown]
# # povgroupの統計情報。毎日一回更新
# ## povgroups_toukei
#
# <dd id="povgroups_toukei_table" class="display-none">
# <table>
# <tbody><tr><th>列名</th><th>型</th><th>内容</th></tr>
# <tr><td>pov</td><td>integer</td><td>povlistテーブルのidを参照する外部キー </td></tr>
# <tr><td>game</td><td>integer</td><td>gamelistテーブルのidを参照する外部キー </td></tr>
# <tr><td>rank</td><td>character(1)</td><td>ランク、A、B、C </td></tr>
# <tr><td>count</td><td>integer</td><td>ランクごとのデータ数</td></tr>
# </tbody></table>
# </dd>
